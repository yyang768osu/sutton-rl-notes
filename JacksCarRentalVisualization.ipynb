# %%
import JacksCarRental
import importlib
importlib.reload(JacksCarRental)
jacks_car_rental = JacksCarRental.JacksCarRental()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
for V, A in jacks_car_rental.policy_iteration(num_iter_improvement=10, gamma=0.9):
    # Visualize Value:
    fig = plt.figure(figsize=(10,6))
    ax = fig.gca(projection='3d')
    # Make data.
    X = np.arange(0, 21)
    Y = np.arange(0, 21)
    X, Y = np.meshgrid(X, Y)
    # Plot the surface.
    surf = ax.plot_surface(X, Y, V, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)
    # Add a color bar which maps values to colors.
    fig.colorbar(surf, shrink=0.5, aspect=5)
    plt.show()
    
    # Visualize Action
    fig = plt.figure(figsize=(10,6))
    plt.imshow(A[::-1,:], cmap=cm.coolwarm)
    plt.subplots_adjust(bottom=0.1, right=0.9, top=0.9)
    cax = plt.axes([0.85, 0.1, 0.075, 0.8])
    plt.colorbar(cax=cax)
    plt.show()
